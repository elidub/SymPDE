# %%
# import numpy as np
# from math import pi
# from pde import *
# import time
# from tqdm import tqdm
# import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

from data import CreatePDE
from plot.plot_pde_data import plot_1d
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pde1 = CreatePDE(pde_exp = 'd2_dx2(u) + u', dt = 1e-3, Nt = 600)
pde1.data, pde1.storage = pde1.get_data(N_samples = 2)
# Out:
# Generating data for d2_dx2(u) + u!: 100%|██████████| 2/2 [00:05<00:00,  2.86s/it]

# %%
s = pde1.storage
d = pde1.data

plot_1d(s, d[0])

# %% [markdown]
# ## Other try-outs

# %%
grid = UnitGrid([64, 64])  # generate grid
state = ScalarField.random_uniform(grid, 0.2, 0.3)  # generate initial condition

eq = DiffusionPDE(diffusivity=0.1)  # define the pde
result = eq.solve(state, t_range=10, dt = 1e-3, adaptive = True)
result.plot()
# Out:
# 100%|██████████| 10.0/10.0 [00:02<00:00,  4.08it/s]

# %%
grid = CartesianGrid([[-1, 1], [0, 2]], [30, 16])  # generate grid
state = ScalarField(grid)  # generate initial condition
# state.insert([0, 1], 1)

eq = DiffusionPDE(0.1)  # define the pde
result = eq.solve(state, t_range=1, dt=0.01)
result.plot(cmap="magma")
# Out:
# 100%|██████████| 1.0/1.0 [00:01<00:00,  1.75s/it]
