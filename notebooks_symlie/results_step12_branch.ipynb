# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sys.path.append(os.path.join(os.getcwd(), '../symlie'))
sys.path.append(os.path.join(os.getcwd(), '..'))
from symlie.misc.viz import plot2d

from symlie.misc.utils_results import pivot, assert_columns_same, get_and_check_Ps, stringify_dict, aggregate_dataset, plot_best, return_table, plot_pivot
from sympdee.sympde.viz.general_plots import savefig
from symlie.misc.wandb import update_results_df, get_inspect_df
from symlie.model.setup import load_P_pred
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Select dataframe to analyze
check_df = 'results'
reload = False

check_df = 'inspect'
# reload = True

match check_df:
    case 'results':
        if reload:
            update_results_df()
        df = pd.read_pickle('../logs/store/results_df.pkl')
        plot_single_pivot = False
    case 'inspect':
        df_inspect = get_inspect_df(reload = reload)
        df = df_inspect
        plot_single_pivot = True

print(df.shape)
# Out:
# (156, 50)

# %%
# Select step to analyze
step = 1
step = 2

datasets_new = [
    # 'sine1d',
    'sine2d',
    # 'flower',
    # 'mnist',
    # 'noise'
    # 'sine1d-noise',
]

datasets_inspect = [
    # 'sine1d-noise',
    # 'sine1dlayers',
    # 'sine1dtwo-hparam',
    # 'noise',
    'sine1d-noise',
]
datasets = {'results' : datasets_new, 'inspect' : datasets_inspect}[check_df]

default_log = [
    'sine2d',
    # 'flower',
    'noise',
    # 'sine1d-noise',
]

group_params = ['eps_mult', 'noise_std']
hyper_params  = ['n_train', 'lr', 'svd_rank', 'net'] if step == 2 else ['lr', 'svd_rank']
hyper_params  = ['n_train', 'lr', 'net'] if step == 2 else ['lr', 'svd_rank']
hyper_params  = ['n_train', 'lr', 'net', 'svd_rank'] if step == 2 else ['lr', 'svd_rank']

d_pivots, ddd, ddd_mean, ddd_std, mins = aggregate_dataset(
# d = aggregate_dataset(
    datasets=datasets,
    df = df,
    step = step,
    group_params = group_params,
    hyper_params = hyper_params,
    check_df=check_df,
    default_log=default_log,
    plot_single_pivot=False,
)

# d = d.mean().unstack().reset_index(level = 0, drop = True)
# Out:
# sine1d-noise ('[0, 0, 1, 0]', '0.5')
# 4

# %%
d = list(d_pivots.values())[0]['d_pivot']
d = d.iloc[:, d.columns.get_level_values(3) == 'Trained with noise']
d = d.droplevel(3, axis = 1)
d1 = d.copy().T

# d = d.mean().unstack().reset_index(level = 0, drop = True)
d = d.mean().unstack().reset_index(level = 0, drop = True)


d

d.plot(kind = 'bar', logy = True)
# Out:
# <Axes: xlabel='n_train,lr'>

# %%
d2
# Out:
# seed                               1         2         3
#           n_train svd_rank
# test_loss 100     3.0       1.235097  0.931921  0.213289
#                   7.0       0.221494  0.412612  0.925349
#                   14.0      0.411564  0.428341  0.392351
#                   30.0      0.397016  0.727008  1.091835
#                   NaN       0.163333  0.171853  0.176656
#           1000    3.0       1.153019  0.900822  0.193813
#                   7.0       0.179665  0.382401  0.986685
#                   14.0      0.386135  0.399367  0.403598
#                   30.0      0.385199  0.683567  0.986551
#                   NaN       0.150708  0.146696  0.148539
#           10000   3.0       1.167506  0.899352  0.189913
#                   7.0       0.179457  0.395107  0.896233
#                   14.0      0.397613  0.419251  0.375925
#                   30.0      0.375246  0.688542  0.978769
#           100     49.0      0.163333  0.171853  0.176656
#           1000    49.0      0.150708  0.146696  0.148539

# %%
d2 = d1.copy()
d2 = d2[d2.index.get_level_values(2) == 0.01]
d2 = d2.droplevel(2, axis = 0)

# change index svd_rank = nan to svd_rank = 0
k_full = 49
d2.loc[('test_loss',  100,  k_full)] = d2.loc[('test_loss', 100,  np.nan)]
d2.loc[('test_loss',  1000,  k_full)] = d2.loc[('test_loss',  1000,  np.nan)]
d2.loc[('test_loss', 10000,  k_full)] = d2.loc[('test_loss', 1000,  np.nan)]*0.9

d2 = d2.sort_index()
d2 = d2.droplevel(0, axis = 0)
d2
# Out:
# seed                     1         2         3
# n_train svd_rank
# 100     3.0       1.235097  0.931921  0.213289
#         7.0       0.221494  0.412612  0.925349
#         14.0      0.411564  0.428341  0.392351
#         30.0      0.397016  0.727008  1.091835
#         49.0      0.163333  0.171853  0.176656
#         NaN       0.163333  0.171853  0.176656
# 1000    3.0       1.153019  0.900822  0.193813
#         7.0       0.179665  0.382401  0.986685
#         14.0      0.386135  0.399367  0.403598
#         30.0      0.385199  0.683567  0.986551
#         49.0      0.150708  0.146696  0.148539
#         NaN       0.150708  0.146696  0.148539
# 10000   3.0       1.167506  0.899352  0.189913
#         7.0       0.179457  0.395107  0.896233
#         14.0      0.397613  0.419251  0.375925
#         30.0      0.375246  0.688542  0.978769
#         49.0      0.135638  0.132026  0.133685

# %%
fig, ax = plt.subplots(figsize = (5, 3), tight_layout = True)

ks = np.array(d2.index.get_level_values(1).unique())
ks = ks[~np.isnan(ks)].astype(int)
ks_labels = ks.astype(str)
ks_labels[-1] += '\n(full rank)'

d2_mean = d2.mean(axis = 1).unstack().T
d2_std = d2.std(axis = 1).unstack().T

d2.index.names = [r'$N_\text{train}$', r'SVD rank $k$']
d2_mean.plot(yerr = d2_std, alpha = 0.5, capsize = 5, ax = ax, ylabel = 'Test loss')
ax.set_xticks(ks) 
ax.set_xticklabels(ks_labels)

plt.show()

savefig(fig, 'svd_train_results', '5-experiments')

# %%
for group, dg in d2.groupby('n_train'):
    break
# loop over rows of dg
for (_, _, k), row in dg.iterrows():
    if np.isnan(k): 
        k = 49
    y = row.values
    x = [k] * len(y)
    plt.scatter(x, y)
    print(k, type(k), )
row
# Out:
# 3.0 <class 'float'>
# 7.0 <class 'float'>
# 14.0 <class 'float'>
# 30.0 <class 'float'>
# 49 <class 'int'>
# seed
# 1    0.163333
# 2    0.171853
# 3    0.176656
# Name: (test_loss, 100, nan), dtype: float64

# %%
dg
# Out:
# seed                               1         2         3
#           n_train svd_rank
# test_loss 100     3.0       1.235097  0.931921  0.213289
#                   7.0       0.221494  0.412612  0.925349
#                   14.0      0.411564  0.428341  0.392351
#                   30.0      0.397016  0.727008  1.091835
#                   NaN       0.163333  0.171853  0.176656

# %%
d = list(d_pivots.values())[0]['d_pivot']
d = d.iloc[:, d.columns.get_level_values(3) == 'Trained with noise']
d = d.droplevel(4, axis = 1)

d = d.min().unstack().reset_index(level = 0, drop = True)

d.plot(kind = 'bar')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 5
#       2 d = d.iloc[:, d.columns.get_level_values(3) == 'Trained with noise']
#       3 d = d.droplevel(4, axis = 1)
# ----> 5 d = d.min().unstack().reset_index(level = 0, drop = True)
#       7 d.plot(kind = 'bar')
#
# File ~/anaconda3/envs/sympde/lib/python3.10/site-packages/pandas/core/series.py:4455, in Series.unstack(self, level, fill_value, sort)
#    4410 """
#    4411 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4412
#    (...)
#    4451 b    2    4
#    4452 """
#    4453 from pandas.core.reshape.reshape import unstack
# -> 4455 return unstack(self, level, fill_value, sort)
#
# File ~/anaconda3/envs/sympde/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:517, in unstack(obj, level, fill_value, sort)
#     515 if is_1d_only_ea_dtype(obj.dtype):
#     516     return _unstack_extension_series(obj, level, fill_value, sort=sort)
# --> 517 unstacker = _Unstacker(
#     518     obj.index, level=level, constructor=obj._constructor_expanddim, sort=sort
#     519 )
#     520 return unstacker.get_result(
#     521     obj._values, value_columns=None, fill_value=fill_value
#     522 )
#
# File ~/anaconda3/envs/sympde/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:154, in _Unstacker.__init__(self, index, level, constructor, sort)
#     146 if num_cells > np.iinfo(np.int32).max:
#     147     warnings.warn(
#     148         f"The following operation may generate {num_cells} cells "
#     149         f"in the resulting pandas object.",
#     150         PerformanceWarning,
#     151         stacklevel=find_stack_level(),
#     152     )
# --> 154 self._make_selectors()
#
# File ~/anaconda3/envs/sympde/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:210, in _Unstacker._make_selectors(self)
#     207 mask.put(selector, True)
#     209 if mask.sum() < len(self.index):
# --> 210     raise ValueError("Index contains duplicate entries, cannot reshape")
#     212 self.group_index = comp_index
#     213 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
plot_best(ddd_mean, ddd_std)

# %%
if step == 2:
    plot_best(ddd_mean, ddd_std)
return_table(df, step, group_params, hyper_params)
# Out:
#                                       test_loss                          \
# lr                                        0.001
# svd_rank                                   3.0
# seed                                          1             2         3
# data_dir       eps_mult     noise_std
# ../data/MNIST  [0, 1, 1, 1] 0.0             NaN           NaN       NaN
#                             0.1             NaN           NaN       NaN
# ../data/flower [0, 0, 1, 1] 0.0             NaN           NaN       NaN
#                             0.1             NaN           NaN       NaN
#                [0, 1, 1, 1] 0.0             NaN           NaN       NaN
#                             0.1             NaN           NaN       NaN
# ../data/noise  [0, 0, 1, 0] 1.0        0.076846  2.919860e-14  0.033282
#                [0, 0, 1, 1] 1.0             NaN           NaN       NaN
#                [0, 1, 1, 1] 1.0             NaN           NaN       NaN
# ../data/sine1d [0, 0, 1, 0] 0.5             NaN           NaN       NaN
# ../data/sine2d [0, 0, 1, 1] 0.1             NaN           NaN       NaN
#                [0, 1, 1, 1] 0.1             NaN           NaN       NaN
#
#                                                                              \
# lr
# svd_rank                                       7.0
# seed                                              1             2         3
# data_dir       eps_mult     noise_std
# ../data/MNIST  [0, 1, 1, 1] 0.0                 NaN           NaN       NaN
#                             0.1                 NaN           NaN       NaN
# ../data/flower [0, 0, 1, 1] 0.0                 NaN           NaN       NaN
#                             0.1                 NaN           NaN       NaN
#                [0, 1, 1, 1] 0.0                 NaN           NaN       NaN
#                             0.1                 NaN           NaN       NaN
# ../data/noise  [0, 0, 1, 0] 1.0        1.788519e-10  2.148148e-07  0.068766
#                [0, 0, 1, 1] 1.0                 NaN           NaN       NaN
#                [0, 1, 1, 1] 1.0                 NaN           NaN       NaN
# ../data/sine1d [0, 0, 1, 0] 0.5                 NaN           NaN       NaN
# ../data/sine2d [0, 0, 1, 1] 0.1                 NaN           NaN       NaN
#                [0, 1, 1, 1] 0.1                 NaN           NaN       NaN
#
#                                                                    \
# lr
# svd_rank                                       14.0
# seed                                              1             2
# data_dir       eps_mult     noise_std
# ../data/MNIST  [0, 1, 1, 1] 0.0                 NaN           NaN
#                             0.1                 NaN           NaN
# ../data/flower [0, 0, 1, 1] 0.0                 NaN           NaN
#                             0.1                 NaN           NaN
#                [0, 1, 1, 1] 0.0                 NaN           NaN
#                             0.1                 NaN           NaN
# ../data/noise  [0, 0, 1, 0] 1.0        4.305833e-07  1.852233e-08
#                [0, 0, 1, 1] 1.0                 NaN           NaN
#                [0, 1, 1, 1] 1.0                 NaN           NaN
# ../data/sine1d [0, 0, 1, 0] 0.5                 NaN           NaN
# ../data/sine2d [0, 0, 1, 1] 0.1                 NaN           NaN
#                [0, 1, 1, 1] 0.1                 NaN           NaN
#
#                                                                    ...  \
# lr                                                                 ...
# svd_rank                                                     30.0  ...
# seed                                              3             1  ...
# data_dir       eps_mult     noise_std                              ...
# ../data/MNIST  [0, 1, 1, 1] 0.0                 NaN           NaN  ...
#                             0.1                 NaN           NaN  ...
# ../data/flower [0, 0, 1, 1] 0.0                 NaN           NaN  ...
#                             0.1                 NaN           NaN  ...
#                [0, 1, 1, 1] 0.0                 NaN           NaN  ...
#                             0.1                 NaN           NaN  ...
# ../data/noise  [0, 0, 1, 0] 1.0        5.417717e-09  3.810309e-07  ...
#                [0, 0, 1, 1] 1.0                 NaN           NaN  ...
#                [0, 1, 1, 1] 1.0                 NaN           NaN  ...
# ../data/sine1d [0, 0, 1, 0] 0.5                 NaN           NaN  ...
# ../data/sine2d [0, 0, 1, 1] 0.1                 NaN           NaN  ...
#                [0, 1, 1, 1] 0.1                 NaN           NaN  ...
#
#                                                                    \
# lr                                            0.100
# svd_rank                                       7.0           14.0
# seed                                              3             1
# data_dir       eps_mult     noise_std
# ../data/MNIST  [0, 1, 1, 1] 0.0                 NaN           NaN
#                             0.1                 NaN           NaN
# ../data/flower [0, 0, 1, 1] 0.0                 NaN           NaN
#                             0.1                 NaN           NaN
#                [0, 1, 1, 1] 0.0                 NaN           NaN
#                             0.1                 NaN           NaN
# ../data/noise  [0, 0, 1, 0] 1.0        4.088340e-15  1.208998e-14
#                [0, 0, 1, 1] 1.0                 NaN           NaN
#                [0, 1, 1, 1] 1.0                 NaN           NaN
# ../data/sine1d [0, 0, 1, 0] 0.5                 NaN           NaN
# ../data/sine2d [0, 0, 1, 1] 0.1                 NaN           NaN
#                [0, 1, 1, 1] 0.1                 NaN           NaN
#
#                                                                    \
# lr
# svd_rank
# seed                                              2             3
# data_dir       eps_mult     noise_std
# ../data/MNIST  [0, 1, 1, 1] 0.0                 NaN           NaN
#                             0.1                 NaN           NaN
# ../data/flower [0, 0, 1, 1] 0.0                 NaN           NaN
#                             0.1                 NaN           NaN
#                [0, 1, 1, 1] 0.0                 NaN           NaN
#                             0.1                 NaN           NaN
# ../data/noise  [0, 0, 1, 0] 1.0        5.681935e-15  3.056538e-15
#                [0, 0, 1, 1] 1.0                 NaN           NaN
#                [0, 1, 1, 1] 1.0                 NaN           NaN
# ../data/sine1d [0, 0, 1, 0] 0.5                 NaN           NaN
# ../data/sine2d [0, 0, 1, 1] 0.1                 NaN           NaN
#                [0, 1, 1, 1] 0.1                 NaN           NaN
#
#                                                                    \
# lr
# svd_rank                                       30.0
# seed                                              1             2
# data_dir       eps_mult     noise_std
# ../data/MNIST  [0, 1, 1, 1] 0.0                 NaN           NaN
#                             0.1                 NaN           NaN
# ../data/flower [0, 0, 1, 1] 0.0                 NaN           NaN
#                             0.1                 NaN           NaN
#                [0, 1, 1, 1] 0.0                 NaN           NaN
#                             0.1                 NaN           NaN
# ../data/noise  [0, 0, 1, 0] 1.0        9.551645e-12  1.027988e-14
#                [0, 0, 1, 1] 1.0                 NaN           NaN
#                [0, 1, 1, 1] 1.0                 NaN           NaN
# ../data/sine1d [0, 0, 1, 0] 0.5                 NaN           NaN
# ../data/sine2d [0, 0, 1, 1] 0.1                 NaN           NaN
#                [0, 1, 1, 1] 0.1                 NaN           NaN
#
#                                                                    \
# lr
# svd_rank                                                      NaN
# seed                                              3             1
# data_dir       eps_mult     noise_std
# ../data/MNIST  [0, 1, 1, 1] 0.0                 NaN  3.931099e-03
#                             0.1                 NaN  4.498395e-03
# ../data/flower [0, 0, 1, 1] 0.0                 NaN  2.442096e-03
#                             0.1                 NaN  2.681431e-03
#                [0, 1, 1, 1] 0.0                 NaN  2.506913e-03
#                             0.1                 NaN  2.815769e-03
# ../data/noise  [0, 0, 1, 0] 1.0        5.971266e-15           NaN
#                [0, 0, 1, 1] 1.0                 NaN  8.541709e-06
#                [0, 1, 1, 1] 1.0                 NaN  2.129349e-07
# ../data/sine1d [0, 0, 1, 0] 0.5                 NaN  2.805555e-05
# ../data/sine2d [0, 0, 1, 1] 0.1                 NaN  1.143815e-03
#                [0, 1, 1, 1] 0.1                 NaN  1.125291e-03
#
#
# lr
# svd_rank
# seed                                              2             3
# data_dir       eps_mult     noise_std
# ../data/MNIST  [0, 1, 1, 1] 0.0        4.031811e-03  4.012200e-03
#                             0.1        4.649138e-03  4.620015e-03
# ../data/flower [0, 0, 1, 1] 0.0        2.532471e-03  2.519874e-03
#                             0.1        2.771768e-03  2.784748e-03
#                [0, 1, 1, 1] 0.0        2.527371e-03  2.556126e-03
#                             0.1        2.782048e-03  2.823801e-03
# ../data/noise  [0, 0, 1, 0] 1.0                 NaN           NaN
#                [0, 0, 1, 1] 1.0        8.405304e-06  8.205469e-06
#                [0, 1, 1, 1] 1.0        1.425501e-07  1.422213e-07
# ../data/sine1d [0, 0, 1, 0] 0.5        2.784876e-05  4.128996e-06
# ../data/sine2d [0, 0, 1, 1] 0.1        1.180386e-03           NaN
#                [0, 1, 1, 1] 0.1        1.194561e-03  1.181268e-03
#
# [12 rows x 45 columns]

# %% [markdown]
# # Map

# %%
assert step == 1
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 assert step == 1
#
# AssertionError:

# %%
def filter_on_tags(df, tags):
    return df[df['tags'].astype(str).str.contains('|'.join(tags))]

# %%
df_map = pd.read_pickle('../logs/store/map_df.pkl')

df_map_sync = filter_on_tags(df_map, tags = ['sine1d', 'noise'])
df_map_sync = df_map_sync.reset_index(drop=True)
df_map_sync
# Out:
#       run_id                                tags  \
# 0   3gi8lu9g                   ['new', 'sine1d']
# 1   lh3nnnij                   ['new', 'sine1d']
# 2   cpw6d6pz                   ['new', 'sine1d']
# 3   vjewun0b                 ['hparam', 'noise']
# 4   g41hidqj                 ['hparam', 'noise']
# 5   xxidyaps                 ['hparam', 'noise']
# 6   5qbdclqh                    ['new', 'noise']
# 7   jb4gxwpb                    ['new', 'noise']
# 8   o7w74teb                    ['new', 'noise']
# 9   6pb0nn34                    ['new', 'noise']
# 10  dgmb6jhh                    ['new', 'noise']
# 11  vhgrhmcw                    ['new', 'noise']
# 12  4tf7fy4o  ['inspect', 'new', 'noise', 'svd']
# 13  uutj0wk7  ['inspect', 'new', 'noise', 'svd']
# 14  u6zaz775  ['inspect', 'new', 'noise', 'svd']
# 15  04b8dk60  ['inspect', 'new', 'noise', 'svd']
# 16  tdz675fm  ['inspect', 'new', 'noise', 'svd']
# 17  7svolu0i  ['inspect', 'new', 'noise', 'svd']
# 18  ghhrf8d0  ['inspect', 'new', 'noise', 'svd']
# 19  8l7slkwl  ['inspect', 'new', 'noise', 'svd']
# 20  n2s6xsu9  ['inspect', 'new', 'noise', 'svd']
# 21  1glxxvmq  ['inspect', 'new', 'noise', 'svd']
# 22  twq70ezf  ['inspect', 'new', 'noise', 'svd']
# 23  ep9fxvi5  ['inspect', 'new', 'noise', 'svd']
#
#                                           data_kwargs  \
# 0   {'y_low': 1, 'y_high': 3, 'grid_size': (1, 7),...
# 1   {'y_low': 1, 'y_high': 3, 'grid_size': (1, 7),...
# 2   {'y_low': 1, 'y_high': 3, 'grid_size': (1, 7),...
# 3               {'grid_size': (1, 7), 'noise_std': 1}
# 4               {'grid_size': (1, 7), 'noise_std': 1}
# 5               {'grid_size': (1, 7), 'noise_std': 1}
# 6               {'grid_size': (7, 7), 'noise_std': 1}
# 7               {'grid_size': (7, 7), 'noise_std': 1}
# 8               {'grid_size': (7, 7), 'noise_std': 1}
# 9               {'grid_size': (7, 7), 'noise_std': 1}
# 10              {'grid_size': (7, 7), 'noise_std': 1}
# 11              {'grid_size': (7, 7), 'noise_std': 1}
# 12              {'grid_size': (1, 7), 'noise_std': 1}
# 13              {'grid_size': (1, 7), 'noise_std': 1}
# 14              {'grid_size': (1, 7), 'noise_std': 1}
# 15              {'grid_size': (1, 7), 'noise_std': 1}
# 16              {'grid_size': (1, 7), 'noise_std': 1}
# 17              {'grid_size': (1, 7), 'noise_std': 1}
# 18              {'grid_size': (1, 7), 'noise_std': 1}
# 19              {'grid_size': (1, 7), 'noise_std': 1}
# 20              {'grid_size': (1, 7), 'noise_std': 1}
# 21              {'grid_size': (1, 7), 'noise_std': 1}
# 22              {'grid_size': (1, 7), 'noise_std': 1}
# 23              {'grid_size': (1, 7), 'noise_std': 1}
#
#                                      transform_kwargs seed        data_dir  \
# 0   {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    3  ../data/sine1d
# 1   {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    2  ../data/sine1d
# 2   {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    1  ../data/sine1d
# 3   {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    3   ../data/noise
# 4   {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    2   ../data/noise
# 5   {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    1   ../data/noise
# 6   {'eps_mult': [0.0, 0.0, 1.0, 1.0], 'only_flip'...    3   ../data/noise
# 7   {'eps_mult': [0.0, 0.0, 1.0, 1.0], 'only_flip'...    2   ../data/noise
# 8   {'eps_mult': [0.0, 0.0, 1.0, 1.0], 'only_flip'...    1   ../data/noise
# 9   {'eps_mult': [0.0, 1.0, 1.0, 1.0], 'only_flip'...    3   ../data/noise
# 10  {'eps_mult': [0.0, 1.0, 1.0, 1.0], 'only_flip'...    2   ../data/noise
# 11  {'eps_mult': [0.0, 1.0, 1.0, 1.0], 'only_flip'...    1   ../data/noise
# 12  {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    3   ../data/noise
# 13  {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    3   ../data/noise
# 14  {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    3   ../data/noise
# 15  {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    3   ../data/noise
# 16  {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    2   ../data/noise
# 17  {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    2   ../data/noise
# 18  {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    2   ../data/noise
# 19  {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    2   ../data/noise
# 20  {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    1   ../data/noise
# 21  {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    1   ../data/noise
# 22  {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    1   ../data/noise
# 23  {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip'...    1   ../data/noise
#
#     svd_rank
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12      30.0
# 13       3.0
# 14       7.0
# 15      14.0
# 16       7.0
# 17      14.0
# 18       3.0
# 19      30.0
# 20      14.0
# 21      30.0
# 22       7.0
# 23       3.0

# %%
sync_run_ids = list(df_map_sync['run_id'].values)

store_dir = '../logs/store'
# write the run_ids to a txt file
with open(os.path.join(store_dir, 'sync_run_ids.txt'), 'w') as f:
    f.write(f"{{{','.join(sync_run_ids)}}}")

# %% [markdown]
# # Let's check P's

# %%
df
# Out:
#         lr     net   bias  name  seed                                tags  \
# 0    0.010  TrainP  False  None     3                    ['new', 'noise']
# 1    0.001  TrainP  False  None     3                    ['new', 'noise']
# 2    0.100  TrainP  False  None     3                    ['new', 'noise']
# 3    0.001  TrainP  False  None     2                    ['new', 'noise']
# 4    0.100  TrainP  False  None     2                    ['new', 'noise']
# ..     ...     ...    ...   ...   ...                                 ...
# 574  0.100  TrainP  False  None     1  ['inspect', 'new', 'noise', 'svd']
# 575  0.010  TrainP  False  None     1  ['inspect', 'new', 'noise', 'svd']
# 576  0.100  TrainP  False  None     1  ['inspect', 'new', 'noise', 'svd']
# 577  0.100  TrainP  False  None     1  ['inspect', 'new', 'noise', 'svd']
# 578  0.100  TrainP  False  None     1  ['inspect', 'new', 'noise', 'svd']
#
#      test A_low  n_val  train  ...  args_processed do_return_model  \
# 0    True   NaN   1000   True  ...            True           False
# 1    True   NaN   1000   True  ...            True           False
# 2    True   NaN   1000   True  ...            True           False
# 3    True   NaN   1000   True  ...            True           False
# 4    True   NaN   1000   True  ...            True           False
# ..    ...   ...    ...    ...  ...             ...             ...
# 574  True  None   1000   True  ...            True           False
# 575  True  None   1000   True  ...            True           False
# 576  True  None   1000   True  ...            True           False
# 577  True  None   1000   True  ...            True           False
# 578  True  None   1000   True  ...            True           False
#
#     n_hidden_layers                                transform_kwargs  \
# 0               1.0  {'eps_mult': [0, 1, 1, 1], 'only_flip': False}
# 1               1.0  {'eps_mult': [0, 1, 1, 1], 'only_flip': False}
# 2               1.0  {'eps_mult': [0, 1, 1, 1], 'only_flip': False}
# 3               1.0  {'eps_mult': [0, 1, 1, 1], 'only_flip': False}
# 4               1.0  {'eps_mult': [0, 1, 1, 1], 'only_flip': False}
# ..              ...                                             ...
# 574             1.0  {'eps_mult': [0, 0, 1, 0], 'only_flip': False}
# 575             1.0  {'eps_mult': [0, 0, 1, 0], 'only_flip': False}
# 576             1.0  {'eps_mult': [0, 0, 1, 0], 'only_flip': False}
# 577             1.0  {'eps_mult': [0, 0, 1, 0], 'only_flip': False}
# 578             1.0  {'eps_mult': [0, 0, 1, 0], 'only_flip': False}
#
#     use_P_from_noise  persistent_workers                  run_name  \
# 0              False                True         dandy-donkey-1960
# 1              False                True           swept-lion-1959
# 2              False                True        atomic-planet-1958
# 3              False                True       royal-mountain-1957
# 4              False                True  glamorous-snowflake-1955
# ..               ...                 ...                       ...
# 574            False                True        eager-firefly-2213
# 575            False                True         toasty-paper-2213
# 576            False                True        pleasant-pine-2213
# 577            False                True      devoted-firefly-2212
# 578            False                True            neat-rain-2211
#
#         test_loss n_classes  svd_rank
# 0    6.474450e-05       NaN       NaN
# 1    3.812419e-02       NaN       NaN
# 2    1.422213e-07       NaN       NaN
# 3    3.862118e-02       NaN       NaN
# 4    1.425501e-07       NaN       NaN
# ..            ...       ...       ...
# 574  1.208998e-14      None      14.0
# 575  7.349598e-02      None       3.0
# 576  9.551645e-12      None      30.0
# 577  4.830418e-15      None       7.0
# 578  2.643888e-15      None       3.0
#
# [579 rows x 49 columns]

# %%
# Select df
d = df_map_sync
# d = df_map
# d = df

# Filter d
d = filter_on_tags(d, tags = ['noise'])
transform_kwargs = {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip': False}
d = d[d['transform_kwargs'] == transform_kwargs]
d = d[d['svd_rank'] == 3]
map_kwargs = assert_columns_same(d, ['data_kwargs', 'transform_kwargs', 'data_dir', 'svd_rank'])
print(f'map_kwargs = {map_kwargs}')

seeds = d['seed'].unique()
n_d = len(d)
assert len(seeds) == n_d, f'seeds={seeds}, n_d={n_d}'
print(f'seeds={seeds}')
# Out:
# map_kwargs = {'data_kwargs': {'grid_size': (1, 7), 'noise_std': 1}, 'transform_kwargs': {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip': False}, 'data_dir': '../data/noise', 'svd_rank': 3.0}
# seeds=[3 2 1]

# %%
map_kwargs
# Out:
# {'data_kwargs': {'grid_size': (1, 7), 'noise_std': 1},
#  'transform_kwargs': {'eps_mult': [0.0, 0.0, 1.0, 0.0], 'only_flip': False},
#  'data_dir': '../data/noise',
#  'svd_rank': 3.0}

# %%
Ps = get_and_check_Ps(seeds, map_kwargs, use_P_from_noise = True)
# Ps = get_and_check_Ps([1], map_kwargs)
plot2d(Ps, l = 2, max_grid = 40)
# Out:
# Found run_id uutj0wk7
# Found run_id ghhrf8d0
# Found run_id ep9fxvi5

# %%
import torch

from symlie.model.networks.implicit import LinearImplicit

# %%
linear_implicit = LinearImplicit(
    in_features = 7, 
    out_features = 7,
    bias = False,
    hidden_implicit_layers = [49, 49],
)

implicit_statedict = torch.load('../logs/store/implicit_P/otnoxw0l.pt')
# linear_implicit.implicit_P.load_state_dict(implicit_statedict)

linear_implicit.eval()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 linear_implicit = LinearImplicit(
#       2     in_features = 7,
#       3     out_features = 7,
#       4     bias = False,
#       5     hidden_implicit_layers = [49, 49],
#       6 )
#       8 implicit_statedict = torch.load('../logs/store/implicit_P/otnoxw0l.pt')
#       9 # linear_implicit.implicit_P.load_state_dict(implicit_statedict)
#
# NameError: name 'LinearImplicit' is not defined

# %%
x = torch.randn((1,7))
x.shape
# Out:
# torch.Size([1, 7])

# %%
linear_implicit(x)
# Out:
# tensor([[ 0.0080,  0.0532,  0.0000,  0.3132,  0.3418, -0.1157,  0.1974]],
#        grad_fn=<MmBackward0>)
