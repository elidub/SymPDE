# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import sys, os

sys.path.append(os.path.join(os.getcwd(), '../symlie'))

from misc.viz import imshow
from data.generate_2d import Create2dData
from data.generate_2d import sine2d, flower
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
N_plot = 10

data_kwargs = {
    'space_length': 100,
    'noise_std'   : 0.01, 
    'y_low'       : 1,
    'y_high'      : 3,
}

transform_kwargs = {
    'eps_mult'  : [0., 1., 1., 1.],
    'only_flip' : True,
}

create_sample_func = sine2d
# create_sample_func = flower

create_data = Create2dData(create_sample_func, **data_kwargs, **transform_kwargs)

out = create_data(N = N_plot)

imshow(out['x'].reshape(N_plot, data_kwargs['space_length'], data_kwargs['space_length']), out['y'])
