# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [
    95,
    5,
    5,
    140,
    55,
    30,
    115,
    135,
    20,
    15,
    20,
    45,
    255,
    145,
    35,
    15,
    35,
    110,
]

y = [
    230,
    300,
    270,
    270,
]

plt.hist(x, density=True)
plt.hist(y, density=True)
plt.show()
